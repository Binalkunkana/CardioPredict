# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - Project - Task</b></center>
# <pre>

# %% [markdown]
# ## We'll start off with a few simple tasks

# %% [markdown]
# ## Load required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
data = pd.read_csv('D:\\DEGREE\\sem-6\\ML\\Project\\Data\\cardio_train.csv')
data
# Out:
#       id;age;gender;height;weight;ap_hi;ap_lo;cholesterol;gluc;smoke;alco;active;cardio
# 0                  0;18393;2;168;62.0;110;80;1;1;0;0;1;0
# 1                  1;20228;1;156;85.0;140;90;3;1;0;0;1;1
# 2                  2;18857;1;165;64.0;130;70;3;1;0;0;0;1
# 3                 3;17623;2;169;82.0;150;100;1;1;0;0;1;1
# 4                  4;17474;1;156;56.0;100;60;1;1;0;0;0;0
# ...                                                  ...
# 69995          99993;19240;2;168;76.0;120;80;1;1;1;0;1;0
# 69996         99995;22601;1;158;126.0;140;90;2;2;0;0;1;1
# 69997         99996;19066;2;183;105.0;180;90;3;1;0;1;0;1
# 69998          99998;22431;1;163;72.0;135;80;1;2;0;0;0;1
# 69999          99999;20540;1;170;72.0;120;80;2;1;0;0;1;0
#
# [70000 rows x 1 columns]

# %% [markdown]
# ## Load the dataset correctly

# %%
data = pd.read_csv('D:\\DEGREE\\sem-6\\ML\\Project\\Data\\cardio_train.csv',sep=';')
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# ## Dataset shape

# %%
data.shape
# Out:
# (70000, 13)

# %% [markdown]
# ## DataType

# %%
data.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# ## Summary statistics

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %% [markdown]
# ## Check target variable distribution

# %%
data['cardio'].value_counts().plot(kind='bar')
plt.title("Target Variable Distribution")
plt.show()

# %% [markdown]
# ## Correlation heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Missing Values

# %%
data.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ## Handle Missing Values

# %%
data.fillna(data.median(), inplace=True)
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# # Detect Outliers

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  **Context:** You are a Data Analyst at "TechCorp".
# HR has asked you to analyze employee data to understand attrition, salary trends, and job satisfaction.
#
# **Instructions:**
# 1. Write your code in the empty cells.

# %% [markdown]
# ### Identify categorical column

# %%
data.select_dtypes(include=['object']).columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### Distribution plots

# %%
data.hist(figsize=(12,10), bins=30)
plt.show()

# %% [markdown]
# ### Correlation vs target

# %%
data.corr()['cardio'].sort_values(ascending=False)
# Out:
# cardio         1.000000
# age            0.238159
# cholesterol    0.221147
# weight         0.181660
# gluc           0.089307
# ap_lo          0.065719
# ap_hi          0.054475
# gender         0.008109
# id             0.003799
# alco          -0.007330
# height        -0.010821
# smoke         -0.015486
# active        -0.035653
# Name: cardio, dtype: float64

# %% [markdown]
# ### percentage of patients with heart disease

# %%
percentage = (data['cardio'].sum() / len(data)) * 100
print("Percentage with heart disease:", percentage)
# Out:
# Percentage with heart disease: 49.97

# %% [markdown]
# ### unique values per column

# %%
data.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64
