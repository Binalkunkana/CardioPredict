# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - Project - Task</b></center>
# <pre>

# %% [markdown]
# ### Create polynomial features manually

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\\DEGREE\\sem-6\\ML\\Project\\\\Data\\cardio_train_cleaned.csv", sep=',')
df.head()
# Out:
#    id    age  gender    height    weight     ap_hi     ap_lo  cholesterol  \
# 0   0  18393       2  0.453030 -0.847913 -0.993525 -0.142823    -0.537322
# 1   1  20228       1 -1.063114  0.760962  0.798737  0.892081     2.407873
# 2   2  18857       1  0.073994 -0.708010  0.201316 -1.177727     2.407873
# 3   3  17623       2  0.579375  0.551109  1.396158  1.926985    -0.537322
# 4   4  17474       1 -1.063114 -1.267619 -1.590946 -2.212631    -0.537322
#
#        gluc  smoke  alco  active  cardio  age_years
# 0 -0.395241      0     0       1       0         50
# 1 -0.395241      0     0       1       1         55
# 2 -0.395241      0     0       0       1         51
# 3 -0.395241      0     0       1       1         48
# 4 -0.395241      0     0       0       0         47

# %% [markdown]
# ### Prepare X and y

# %%
X = df.drop(columns=['cardio','id','age'])
y = df['cardio']

# %% [markdown]
# ### split data into training testing

# %%
from sklearn.model_selection import train_test_split
X_Train,X_Test,y_Train,y_Test = train_test_split(X,y,train_size=0.2,random_state=42)

# %%
y_Test
# Out:
# 41738    0
# 6329     0
# 35964    1
# 25806    1
# 42755    1
#         ..
# 16672    1
# 15531    1
# 66829    1
# 48282    1
# 582      1
# Name: cardio, Length: 54962, dtype: int64

# %%
X_Test
# Out:
#        gender    height    weight     ap_hi     ap_lo  cholesterol      gluc  \
# 41738       1 -0.052352  0.271305  0.201316 -0.142823    -0.537322 -0.395241
# 6329        1 -0.557733 -1.337570 -0.993525 -0.142823    -0.537322 -0.395241
# 35964       1  0.073994  0.271305  0.201316  0.892081     2.407873 -0.395241
# 25806       2  0.453030  0.271305  0.201316 -1.177727    -0.537322  1.352898
# 42755       2  0.832065  2.299886 -0.396105 -0.142823    -0.537322 -0.395241
# ...       ...       ...       ...       ...       ...          ...       ...
# 16672       1 -0.810424 -0.078451  0.201316 -0.142823     2.407873  3.101036
# 15531       1 -0.936769  0.411207  0.798737 -0.142823     2.407873 -0.395241
# 66829       2  0.579375 -0.498157  0.201316  0.892081     2.407873  3.101036
# 48282       2  1.211101  2.020082  1.396158 -0.142823     2.407873  3.101036
# 582         2 -0.936769 -0.987815 -0.396105 -0.142823    -0.537322 -0.395241
#
#        smoke  alco  active  age_years
# 41738      0     0       1         53
# 6329       0     0       1         41
# 35964      0     0       0         62
# 25806      0     0       1         61
# 42755      0     0       0         45
# ...      ...   ...     ...        ...
# 16672      0     0       1         61
# 15531      0     0       1         53
# 66829      0     0       1         52
# 48282      1     0       1         62
# 582        0     0       1         50
#
# [54962 rows x 11 columns]

# %% [markdown]
# ### logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_Train, y_Train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Accuracy 
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_Test)
accuracy_score(y_Test, y_pred)
# Out:
# 0.7253011171354754

# %%
#Confusion Matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_Test, y_pred), annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
#Classification Report
from sklearn.metrics import classification_report

print(classification_report(y_Test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74     27657
#            1       0.75      0.66      0.71     27305
#
#     accuracy                           0.73     54962
#    macro avg       0.73      0.72      0.72     54962
# weighted avg       0.73      0.73      0.72     54962

# %%
#Using Random Forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_Train, y_Train)

rf_pred = rf.predict(X_Test)
accuracy_score(y_Test, rf_pred)
# Out:
# 0.710763800443943

# %% [markdown]
# ### Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_Train, y_Train)

rf_pred = rf.predict(X_Test)
accuracy_score(y_Test, rf_pred)
# Out:
# 0.710763800443943

# %%
import pandas as pd

importance = pd.Series(rf.feature_importances_, index=X.columns)
importance.sort_values(ascending=False).head(10)
# Out:
# weight         0.217226
# height         0.194299
# ap_hi          0.193958
# age_years      0.175866
# ap_lo          0.089133
# cholesterol    0.044519
# gender         0.022427
# gluc           0.022401
# active         0.018977
# smoke          0.011860
# dtype: float64

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_Test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7253011171354754

# %%
accuracy_percent = accuracy * 100
print(f"Accuracy: {accuracy_percent:.2f}%")
# Out:
# Accuracy: 72.53%

# %%
#next perform decision tree then naive bais and then many other models

# %%
#classification_report
from sklearn.metrics import classification_report
print(classification_report(y_Test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74     27657
#            1       0.75      0.66      0.71     27305
#
#     accuracy                           0.73     54962
#    macro avg       0.73      0.72      0.72     54962
# weighted avg       0.73      0.73      0.72     54962

# %%
#ROC And AUC curve

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

y_prob = model.predict_proba(X_Test)[:,1]

fpr, tpr, _ = roc_curve(y_Test, y_prob)

plt.plot(fpr, tpr, label="AUC = " + str(roc_auc_score(y_Test, y_prob)))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
#compare train and test accuracy 
train_acc = model.score(X_Train, y_Train)
test_acc = model.score(X_Test, y_Test)

print("Train Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
# Out:
# Train Accuracy: 0.7321688500727802
# Test Accuracy: 0.7253011171354754

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Accuracy
print("Accuracy:", accuracy_score(y_Test, y_pred)*100, "%")

# Confusion Matrix
print("Confusion Matrix:\n", confusion_matrix(y_Test, y_pred))

# Classification Report
print(classification_report(y_Test, y_pred))

# Train vs Test Accuracy
print("Train Accuracy:", model.score(X_Train, y_Train))
print("Test Accuracy:", model.score(X_Test, y_Test))
# Out:
# Accuracy: 72.53011171354754 %
# Confusion Matrix:
#  [[21788  5869]
#  [ 9229 18076]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74     27657
#            1       0.75      0.66      0.71     27305
#
#     accuracy                           0.73     54962
#    macro avg       0.73      0.72      0.72     54962
# weighted avg       0.73      0.73      0.72     54962
#
# Train Accuracy: 0.7321688500727802
# Test Accuracy: 0.7253011171354754

# %% [markdown]
# ### Check Overfitting / Underfitting

# %%
train_acc = model.score(X_Train, y_Train)
test_acc = model.score(X_Test, y_Test)

print("Training Accuracy:", train_acc*100)
print("Testing Accuracy:", test_acc*100)
# Out:
# Training Accuracy: 73.21688500727802
# Testing Accuracy: 72.53011171354754

# %% [markdown]
# ### Hyperparameter Tunig

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    "n_estimators": [50,100,200],
    "max_depth": [None,5,10],
    "min_samples_split": [2,5,10]
}

grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, scoring="accuracy")
grid.fit(X_Train, y_Train)

print("Best Parameters:", grid.best_params_)
print("Best CV Accuracy:", grid.best_score_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# Best CV Accuracy: 0.738136826783115
