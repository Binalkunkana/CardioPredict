# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>ML </b></center>
#
# <center><b><h1>Machine Learning Project Task</b></center>
# <pre>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('cardio_train_cleaned.csv')
data
# Out:
#           id    age  gender    height    weight     ap_hi     ap_lo  \
# 0          0  18393       2  0.453030 -0.847913 -0.993525 -0.142823
# 1          1  20228       1 -1.063114  0.760962  0.798737  0.892081
# 2          2  18857       1  0.073994 -0.708010  0.201316 -1.177727
# 3          3  17623       2  0.579375  0.551109  1.396158  1.926985
# 4          4  17474       1 -1.063114 -1.267619 -1.590946 -2.212631
# ...      ...    ...     ...       ...       ...       ...       ...
# 68697  99993  19240       2  0.453030  0.131402 -0.396105 -0.142823
# 68698  99995  22601       1 -0.810424  3.628957  0.798737  0.892081
# 68699  99996  19066       2  2.348209  2.159984  3.188421  0.892081
# 68700  99998  22431       1 -0.178697 -0.148402  0.500027 -0.142823
# 68701  99999  20540       1  0.705720 -0.148402 -0.396105 -0.142823
#
#        cholesterol      gluc  smoke  alco  active  cardio  age_years
# 0        -0.537322 -0.395241      0     0       1       0         50
# 1         2.407873 -0.395241      0     0       1       1         55
# 2         2.407873 -0.395241      0     0       0       1         51
# 3        -0.537322 -0.395241      0     0       1       1         48
# 4        -0.537322 -0.395241      0     0       0       0         47
# ...            ...       ...    ...   ...     ...     ...        ...
# 68697    -0.537322 -0.395241      1     0       1       0         52
# 68698     0.935276  1.352898      0     0       1       1         61
# 68699     2.407873 -0.395241      0     1       0       1         52
# 68700    -0.537322  1.352898      0     0       0       1         61
# 68701     0.935276 -0.395241      0     0       1       0         56
#
# [68702 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
X = data.drop(columns=['cardio','id','age'])
y = data['cardio']

# %%
X_Test,X_Train,y_Test,y_Train = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
y_Test
# Out:
# 27286    0
# 51758    1
# 36796    1
# 45622    0
# 40191    1
#         ..
# 37194    0
# 6265     0
# 54886    1
# 860      1
# 15795    1
# Name: cardio, Length: 54961, dtype: int64

# %%
X_Test
# Out:
#        gender    height    weight     ap_hi     ap_lo  cholesterol      gluc  \
# 27286       2  1.716483 -0.288304 -0.396105 -1.177727    -0.537322 -0.395241
# 51758       2  0.453030  1.460473  0.201316 -0.142823     2.407873 -0.395241
# 36796       2  0.579375 -0.638059 -0.993525 -1.177727    -0.537322 -0.395241
# 45622       1  0.832065  0.760962 -0.396105  0.892081    -0.537322  3.101036
# 40191       1 -1.568496  0.131402  0.798737  0.892081     0.935276 -0.395241
# ...       ...       ...       ...       ...       ...          ...       ...
# 37194       1 -0.557733 -0.638059  0.201316 -2.212631    -0.537322 -0.395241
# 6265        2  0.453030  0.411207 -0.993525 -1.177727    -0.537322 -0.395241
# 54886       2  0.705720  0.131402 -0.396105 -0.142823     0.935276 -0.395241
# 860         1 -1.063114 -0.987815  0.201316 -0.142823     2.407873  3.101036
# 15795       2  0.453030 -0.008500  1.396158  1.926985    -0.537322 -0.395241
#
#        smoke  alco  active  age_years
# 27286      1     1       1         54
# 51758      0     0       0         57
# 36796      0     0       1         47
# 45622      0     0       0         53
# 40191      0     0       1         51
# ...      ...   ...     ...        ...
# 37194      0     0       0         54
# 6265       1     1       1         39
# 54886      1     0       1         61
# 860        0     0       1         60
# 15795      0     0       1         55
#
# [54961 rows x 11 columns]

# %%
model = DecisionTreeClassifier()
model.fit(X_Train,y_Train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier

data = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=50,
    min_samples_leaf=20,
    random_state=42
)

data.fit(X_Train, y_Train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=50,
#                        random_state=42)

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(
    data,
    feature_names=X_Train.columns,
    class_names=['No Disease', 'Disease'],
    filled=True,
    rounded=True
)
plt.show()
